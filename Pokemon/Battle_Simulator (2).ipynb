# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns
import requests
from bs4 import BeautifulSoup

# %%
filename = "web_scraped_pokemon.csv"
df = pd.read_csv(filename).drop(columns= ['Unnamed: 0'])
df[0:10]
# Out:
#     hp  attack  defense  sp_Attack  sp_Defense  speed  total         name  \
# 0   70     110       80         95          60     70    485      Flapple
# 1   70      85      145         60          55     65    480     Orthworm
# 2   38      47       35         33          35     57    245     Rookidee
# 3   40      61       54         45          45     65    310   Sprigatito
# 4   45      45       30         55          40     50    265     Impidimp
# 5   60      65       65        134         114     70    508  Polteageist
# 6  125     100       80         85          75     55    520  Dudunsparce
# 7   50      50       45         40          45     75    305    Tandemaus
# 8   50      64       50         38          38     44    284      Chewtle
# 9   50      45       45         35          64     58    297    Tinkatink
#
#     type1   type2
# 0   Grass  Dragon
# 1   Steel
# 2  Flying
# 3   Grass
# 4    Dark   Fairy
# 5   Ghost
# 6  Normal
# 7  Normal
# 8   Water
# 9   Fairy   Steel

# %%
def type_advantage(attacker,defender):
       
    att_types = []
    att_types.append(attacker['type1'].values[0])
    if attacker['type2'].values[0] != " ":
        att_types.append(attacker['type2'].values[0])
    
    def_types = []
    def_types.append(defender['type1'].values[0])
    if defender['type2'].values[0] != " ":
        def_types.append(defender['type2'].values[0])
    
    
    Effectiveness = 1
    
    for type_ in att_types:
        
        super_effective = []
        not_very_effective = []
        
        url = f'https://pokemondb.net/type/{type_}'
        data  = requests.get(url).text
        soup = BeautifulSoup(data,"lxml")
        bm = soup.body.main
        bmd = bm.find('div', class_="grid-col span-md-6 span-lg-12")
        bmdp = bmd.find_all('p', class_="type-fx-list")
        
        
        for a in bmdp[0].find_all('a'):
            super_effective.append(a.text)
            
        for a in bmdp[1].find_all('a'):
            not_very_effective.append(a.text)
        
        
        se = set(super_effective)-set(def_types)
        nve = set(not_very_effective)-set(def_types)
        
        if (len(not_very_effective) - len(nve)) == 1:
            Effectiveness = .5
        if (len(not_very_effective) - len(nve)) == 2:
            Effectiveness = .25
        if (len(super_effective) - len(se)) == 1:
            Effectiveness = 2
        if (len(super_effective) - len(se)) == 2:
            Effectiveness = 4

    return  Effectiveness

# %%
type_advantage(pokemon1,pokemon2)
# Out:
# 2

# %%
L = 50

def damage(attacker,defender):
    L=50
    BP = 50
    A = int(attacker['attack'])
    D = int(defender['defense'])
    Sp_A = int(attacker['sp_Attack'])
    Sp_D = int(defender['sp_Defense'])
    
    A_dmg = ((2*L + 10)/250 * A/D * BP + 2) * type_advantage(attacker, defender)
    Sp_A_dmg = ((2*L + 10)/250 * Sp_A/Sp_D * BP + 2) * type_advantage(attacker, defender)
    
    if A_dmg > Sp_A_dmg:
        dmg = A_dmg
        if dmg > ((2*L + 10)/250 * A/D * BP + 2):
            print('      Its super effective!')
        if dmg < ((2*L + 10)/250 * A/D * BP + 2):
            print('      Its not very effective')
    else:
        dmg = Sp_A_dmg
        if dmg > ((2*L + 10)/250 * Sp_A/Sp_D * BP + 2):
            print('      Its super effective!')
        if dmg < ((2*L + 10)/250 * Sp_A/Sp_D * BP + 2):
            print('      Its not very effective')
        
    return int(dmg)

# %%
def battle(poke1, poke2):
    poke1_name = poke1['name'].values[0]
    poke2_name = poke2['name'].values[0]
    poke1_hp = poke1['hp'].values[0]
    poke2_hp = poke2['hp'].values[0]
    
    print(f'{poke1_name} has {poke1_hp} starting health')
    print(f'{poke2_name} has {poke2_hp} starting health \n')
    
    victor = ""
    while int(poke1_hp) >0 and int(poke2_hp) >0:
    
        if int(poke1['speed']) > int(poke2['speed']):
            print(f'Your {poke1_name} attacked {poke2_name},')
            dmg = damage(pokemon1, pokemon2)
            poke2_hp = poke2_hp - dmg
            print(f'      {poke2_name} took {dmg} damage, HP: {poke2_hp} \n')
            
            
            if poke2_hp <= 0:
                print(f' \n{poke2_name} fainted \n')
                victor = poke1_name
                break
            else:
                print(f'Their {poke2_name} attacked {poke1_name},')
                dmg = damage(pokemon2, pokemon1)
                poke1_hp = poke1_hp - dmg
                print(f'      {poke1_name} took {dmg} damage, HP: {poke1_hp} \n')
                
        else:
            print(f'Their {poke2_name} attacked {poke1_name},')
            dmg = damage(pokemon2, pokemon1)
            poke1_hp = poke1_hp - dmg
            print(f'      {poke1_name} took {dmg} damage, HP: {poke1_hp} \n')
            
            
            if poke1_hp <= 0:
                print(f' \n{poke1_name} fainted \n')
                victor= poke2_name
                break
                
            else:
                print(f'Your {poke1_name} attacked {poke2_name},')
                dmg = damage(pokemon1, pokemon2)
                poke2_hp = poke2_hp - dmg
                print(f'      {poke2_name} took {dmg} damage, HP: {poke2_hp} \n')
                
        if poke1_hp <= 0:
            print(f'{poke1_name} fainted \n')
            victor = poke2_name
        if poke2_hp <= 0:
            print(f'{poke2_name} fainted \n')
            victor = poke1_name
    print("-------------------------------------------")  
    return victor

# %%
pokemon1_name = 'Toedscruel'
pokemon2_name = 'Dudunsparce'

pokemon1 = df[df['name'] == f'{pokemon1_name}']
pokemon2 = df[df['name'] == f'{pokemon2_name}']
pokemon1
# Out:
#     hp  attack  defense  sp_Attack  sp_Defense  speed  total        name  \
# 12  80      70       65         80         120    100    515  Toedscruel
#
#      type1  type2
# 12  Ground  Grass

# %%
battle(pokemon1,pokemon2)
# Out:
# Toedscruel has 80 starting health
# Dudunsparce has 125 starting health
#
# Your Toedscruel attacked Dudunsparce,
#       Dudunsparce took 25 damage, HP: 100
#
# Their Dudunsparce attacked Toedscruel,
#       Toedscruel took 35 damage, HP: 45
#
# Your Toedscruel attacked Dudunsparce,
#       Dudunsparce took 25 damage, HP: 75
#
# Their Dudunsparce attacked Toedscruel,
#       Toedscruel took 35 damage, HP: 10
#
# Your Toedscruel attacked Dudunsparce,
#       Dudunsparce took 25 damage, HP: 50
#
# Their Dudunsparce attacked Toedscruel,
#       Toedscruel took 35 damage, HP: -25
#
# Toedscruel fainted
#
# -------------------------------------------
# 'Dudunsparce'

# %%
total_battles = len(df)
all_pokemon = df['name'][0:total_battles]
win_counter = 0


for pokemon in all_pokemon:
    pokemon2 = df[df['name'] == f'{pokemon}']
    
    if battle(pokemon1,pokemon2) == pokemon1_name:
        win_counter += 1
win_perc = str((win_counter/total_battles)*100)
print(f'{pokemon1_name} won {win_perc}% of battles')
# Out:
# Toedscruel has 80 starting health
# Flapple has 70 starting health
#
# Your Toedscruel attacked Flapple,
#       Its not very effective
#       Flapple took 7 damage, HP: 63
#
# Their Flapple attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 78 damage, HP: 2
#
# Your Toedscruel attacked Flapple,
#       Its not very effective
#       Flapple took 7 damage, HP: 56
#
# Their Flapple attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 78 damage, HP: -76
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Orthworm has 70 starting health
#
# Your Toedscruel attacked Orthworm,
#       Its not very effective
#       Orthworm took 17 damage, HP: 53
#
# Their Orthworm attacked Toedscruel,
#       Toedscruel took 30 damage, HP: 50
#
# Your Toedscruel attacked Orthworm,
#       Its not very effective
#       Orthworm took 17 damage, HP: 36
#
# Their Orthworm attacked Toedscruel,
#       Toedscruel took 30 damage, HP: 20
#
# Your Toedscruel attacked Orthworm,
#       Its not very effective
#       Orthworm took 17 damage, HP: 19
#
# Their Orthworm attacked Toedscruel,
#       Toedscruel took 30 damage, HP: -10
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Rookidee has 38 starting health
#
# Your Toedscruel attacked Rookidee,
#       Its not very effective
#       Rookidee took 26 damage, HP: 12
#
# Their Rookidee attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 35 damage, HP: 45
#
# Your Toedscruel attacked Rookidee,
#       Its not very effective
#       Rookidee took 26 damage, HP: -14
#
#
# Rookidee fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Sprigatito has 40 starting health
#
# Your Toedscruel attacked Sprigatito,
#       Its not very effective
#       Sprigatito took 20 damage, HP: 20
#
# Their Sprigatito attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 45 damage, HP: 35
#
# Your Toedscruel attacked Sprigatito,
#       Its not very effective
#       Sprigatito took 20 damage, HP: 0
#
#
# Sprigatito fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Impidimp has 45 starting health
#
# Your Toedscruel attacked Impidimp,
#       Impidimp took 53 damage, HP: -8
#
#
# Impidimp fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Polteageist has 60 starting health
#
# Your Toedscruel attacked Polteageist,
#       Polteageist took 25 damage, HP: 35
#
# Their Polteageist attacked Toedscruel,
#       Toedscruel took 26 damage, HP: 54
#
# Your Toedscruel attacked Polteageist,
#       Polteageist took 25 damage, HP: 10
#
# Their Polteageist attacked Toedscruel,
#       Toedscruel took 26 damage, HP: 28
#
# Your Toedscruel attacked Polteageist,
#       Polteageist took 25 damage, HP: -15
#
#
# Polteageist fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Dudunsparce has 125 starting health
#
# Your Toedscruel attacked Dudunsparce,
#       Dudunsparce took 25 damage, HP: 100
#
# Their Dudunsparce attacked Toedscruel,
#       Toedscruel took 35 damage, HP: 45
#
# Your Toedscruel attacked Dudunsparce,
#       Dudunsparce took 25 damage, HP: 75
#
# Their Dudunsparce attacked Toedscruel,
#       Toedscruel took 35 damage, HP: 10
#
# Your Toedscruel attacked Dudunsparce,
#       Dudunsparce took 25 damage, HP: 50
#
# Their Dudunsparce attacked Toedscruel,
#       Toedscruel took 35 damage, HP: -25
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Tandemaus has 50 starting health
#
# Your Toedscruel attacked Tandemaus,
#       Tandemaus took 41 damage, HP: 9
#
# Their Tandemaus attacked Toedscruel,
#       Toedscruel took 18 damage, HP: 62
#
# Your Toedscruel attacked Tandemaus,
#       Tandemaus took 41 damage, HP: -32
#
#
# Tandemaus fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Chewtle has 50 starting health
#
# Your Toedscruel attacked Chewtle,
#       Its super effective!
#       Chewtle took 96 damage, HP: -46
#
#
# Chewtle fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Tinkatink has 50 starting health
#
# Your Toedscruel attacked Tinkatink,
#       Its not very effective
#       Tinkatink took 18 damage, HP: 32
#
# Their Tinkatink attacked Toedscruel,
#       Toedscruel took 17 damage, HP: 63
#
# Your Toedscruel attacked Tinkatink,
#       Its not very effective
#       Tinkatink took 18 damage, HP: 14
#
# Their Tinkatink attacked Toedscruel,
#       Toedscruel took 17 damage, HP: 46
#
# Your Toedscruel attacked Tinkatink,
#       Its not very effective
#       Tinkatink took 18 damage, HP: -4
#
#
# Tinkatink fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Veluza has 90 starting health
#
# Your Toedscruel attacked Veluza,
#       Its super effective!
#       Veluza took 58 damage, HP: 32
#
# Their Veluza attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 73 damage, HP: 7
#
# Your Toedscruel attacked Veluza,
#       Its super effective!
#       Veluza took 58 damage, HP: -26
#
#
# Veluza fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Glimmora has 83 starting health
#
# Your Toedscruel attacked Glimmora,
#       Its super effective!
#       Glimmora took 47 damage, HP: 36
#
# Their Glimmora attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 51 damage, HP: 29
#
# Your Toedscruel attacked Glimmora,
#       Its super effective!
#       Glimmora took 47 damage, HP: -11
#
#
# Glimmora fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Toedscruel has 80 starting health
#
# Their Toedscruel attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 51 damage, HP: 29
#
# Your Toedscruel attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 51 damage, HP: 29
#
# Their Toedscruel attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 51 damage, HP: -22
#
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Cyclizar has 70 starting health
#
# Their Cyclizar attacked Toedscruel,
#       Toedscruel took 34 damage, HP: 46
#
# Your Toedscruel attacked Cyclizar,
#       Its not very effective
#       Cyclizar took 14 damage, HP: 56
#
# Their Cyclizar attacked Toedscruel,
#       Toedscruel took 34 damage, HP: 12
#
# Your Toedscruel attacked Cyclizar,
#       Its not very effective
#       Cyclizar took 14 damage, HP: 42
#
# Their Cyclizar attacked Toedscruel,
#       Toedscruel took 34 damage, HP: -22
#
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Squawkabilly has 82 starting health
#
# Your Toedscruel attacked Squawkabilly,
#       Its not very effective
#       Squawkabilly took 18 damage, HP: 64
#
# Their Squawkabilly attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 68 damage, HP: 12
#
# Your Toedscruel attacked Squawkabilly,
#       Its not very effective
#       Squawkabilly took 18 damage, HP: 46
#
# Their Squawkabilly attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 68 damage, HP: -56
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Capsakid has 50 starting health
#
# Your Toedscruel attacked Capsakid,
#       Its not very effective
#       Capsakid took 23 damage, HP: 27
#
# Their Capsakid attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 45 damage, HP: 35
#
# Your Toedscruel attacked Capsakid,
#       Its not very effective
#       Capsakid took 23 damage, HP: 4
#
# Their Capsakid attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 45 damage, HP: -10
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Gholdengo has 87 starting health
#
# Your Toedscruel attacked Gholdengo,
#       Its not very effective
#       Gholdengo took 10 damage, HP: 77
#
# Their Gholdengo attacked Toedscruel,
#       Toedscruel took 26 damage, HP: 54
#
# Your Toedscruel attacked Gholdengo,
#       Its not very effective
#       Gholdengo took 10 damage, HP: 67
#
# Their Gholdengo attacked Toedscruel,
#       Toedscruel took 26 damage, HP: 28
#
# Your Toedscruel attacked Gholdengo,
#       Its not very effective
#       Gholdengo took 10 damage, HP: 57
#
# Their Gholdengo attacked Toedscruel,
#       Toedscruel took 26 damage, HP: 2
#
# Your Toedscruel attacked Gholdengo,
#       Its not very effective
#       Gholdengo took 10 damage, HP: 47
#
# Their Gholdengo attacked Toedscruel,
#       Toedscruel took 26 damage, HP: -24
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Toedscool has 40 starting health
#
# Your Toedscruel attacked Toedscool,
#       Its super effective!
#       Toedscool took 92 damage, HP: -52
#
#
# Toedscool fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Gimmighoul has 45 starting health
#
# Your Toedscruel attacked Gimmighoul,
#       Gimmighoul took 27 damage, HP: 18
#
# Their Gimmighoul attacked Toedscruel,
#       Toedscruel took 15 damage, HP: 65
#
# Your Toedscruel attacked Gimmighoul,
#       Gimmighoul took 27 damage, HP: -9
#
#
# Gimmighoul fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Bellibolt has 109 starting health
#
# Your Toedscruel attacked Bellibolt,
#       Its super effective!
#       Bellibolt took 46 damage, HP: 63
#
# Their Bellibolt attacked Toedscruel,
#       Its not very effective
#       Toedscruel took 11 damage, HP: 69
#
# Your Toedscruel attacked Bellibolt,
#       Its super effective!
#       Bellibolt took 46 damage, HP: 17
#
# Their Bellibolt attacked Toedscruel,
#       Its not very effective
#       Toedscruel took 11 damage, HP: 58
#
# Your Toedscruel attacked Bellibolt,
#       Its super effective!
#       Bellibolt took 46 damage, HP: -29
#
#
# Bellibolt fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Tadbulb has 61 starting health
#
# Your Toedscruel attacked Tadbulb,
#       Its super effective!
#       Tadbulb took 104 damage, HP: -43
#
#
# Tadbulb fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Applin has 40 starting health
#
# Your Toedscruel attacked Applin,
#       Its not very effective
#       Applin took 11 damage, HP: 29
#
# Their Applin attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 31 damage, HP: 49
#
# Your Toedscruel attacked Applin,
#       Its not very effective
#       Applin took 11 damage, HP: 18
#
# Their Applin attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 31 damage, HP: 18
#
# Your Toedscruel attacked Applin,
#       Its not very effective
#       Applin took 11 damage, HP: 7
#
# Their Applin attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 31 damage, HP: -13
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Frigibax has 65 starting health
#
# Your Toedscruel attacked Frigibax,
#       Its not very effective
#       Frigibax took 20 damage, HP: 45
#
# Their Frigibax attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 109 damage, HP: -29
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Grafaiai has 63 starting health
#
# Their Grafaiai attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 68 damage, HP: 12
#
# Your Toedscruel attacked Grafaiai,
#       Its not very effective
#       Grafaiai took 13 damage, HP: 50
#
# Their Grafaiai attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 68 damage, HP: -56
#
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Smoliv has 41 starting health
#
# Your Toedscruel attacked Smoliv,
#       Its not very effective
#       Smoliv took 18 damage, HP: 23
#
# Their Smoliv attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 27 damage, HP: 53
#
# Your Toedscruel attacked Smoliv,
#       Its not very effective
#       Smoliv took 18 damage, HP: 5
#
# Their Smoliv attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 27 damage, HP: 26
#
# Your Toedscruel attacked Smoliv,
#       Its not very effective
#       Smoliv took 18 damage, HP: -13
#
#
# Smoliv fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Arboliva has 78 starting health
#
# Your Toedscruel attacked Arboliva,
#       Its not very effective
#       Arboliva took 9 damage, HP: 69
#
# Their Arboliva attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 50 damage, HP: 30
#
# Your Toedscruel attacked Arboliva,
#       Its not very effective
#       Arboliva took 9 damage, HP: 60
#
# Their Arboliva attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 50 damage, HP: -20
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Finizen has 70 starting health
#
# Your Toedscruel attacked Finizen,
#       Its super effective!
#       Finizen took 92 damage, HP: -22
#
#
# Finizen fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Chien-Pao has 80 starting health
#
# Their Chien-Pao attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 170 damage, HP: -90
#
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Varoom has 45 starting health
#
# Your Toedscruel attacked Varoom,
#       Its not very effective
#       Varoom took 10 damage, HP: 35
#
# Their Varoom attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 51 damage, HP: 29
#
# Your Toedscruel attacked Varoom,
#       Its not very effective
#       Varoom took 10 damage, HP: 25
#
# Their Varoom attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 51 damage, HP: -22
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Miraidon has 100 starting health
#
# Their Miraidon attacked Toedscruel,
#       Its not very effective
#       Toedscruel took 15 damage, HP: 65
#
# Your Toedscruel attacked Miraidon,
#       Its not very effective
#       Miraidon took 8 damage, HP: 92
#
# Their Miraidon attacked Toedscruel,
#       Its not very effective
#       Toedscruel took 15 damage, HP: 50
#
# Your Toedscruel attacked Miraidon,
#       Its not very effective
#       Miraidon took 8 damage, HP: 84
#
# Their Miraidon attacked Toedscruel,
#       Its not very effective
#       Toedscruel took 15 damage, HP: 35
#
# Your Toedscruel attacked Miraidon,
#       Its not very effective
#       Miraidon took 8 damage, HP: 76
#
# Their Miraidon attacked Toedscruel,
#       Its not very effective
#       Toedscruel took 15 damage, HP: 20
#
# Your Toedscruel attacked Miraidon,
#       Its not very effective
#       Miraidon took 8 damage, HP: 68
#
# Their Miraidon attacked Toedscruel,
#       Its not very effective
#       Toedscruel took 15 damage, HP: 5
#
# Your Toedscruel attacked Miraidon,
#       Its not very effective
#       Miraidon took 8 damage, HP: 60
#
# Their Miraidon attacked Toedscruel,
#       Its not very effective
#       Toedscruel took 15 damage, HP: -10
#
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Chi-Yu has 55 starting health
#
# Their Chi-Yu attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 58 damage, HP: 22
#
# Your Toedscruel attacked Chi-Yu,
#       Its not very effective
#       Chi-Yu took 10 damage, HP: 45
#
# Their Chi-Yu attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 58 damage, HP: -36
#
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Quaxly has 55 starting health
#
# Your Toedscruel attacked Quaxly,
#       Its super effective!
#       Quaxly took 82 damage, HP: -27
#
#
# Quaxly fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Grimmsnarl has 95 starting health
#
# Your Toedscruel attacked Grimmsnarl,
#       Grimmsnarl took 25 damage, HP: 70
#
# Their Grimmsnarl attacked Toedscruel,
#       Toedscruel took 42 damage, HP: 38
#
# Your Toedscruel attacked Grimmsnarl,
#       Grimmsnarl took 25 damage, HP: 45
#
# Their Grimmsnarl attacked Toedscruel,
#       Toedscruel took 42 damage, HP: -4
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Meowscarada has 76 starting health
#
# Their Meowscarada attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 78 damage, HP: 2
#
# Your Toedscruel attacked Meowscarada,
#       Its not very effective
#       Meowscarada took 13 damage, HP: 63
#
# Their Meowscarada attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 78 damage, HP: -76
#
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Naclstack has 60 starting health
#
# Your Toedscruel attacked Naclstack,
#       Its super effective!
#       Naclstack took 58 damage, HP: 2
#
# Their Naclstack attacked Toedscruel,
#       Its not very effective
#       Toedscruel took 11 damage, HP: 69
#
# Your Toedscruel attacked Naclstack,
#       Its super effective!
#       Naclstack took 58 damage, HP: -56
#
#
# Naclstack fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Barraskewda has 61 starting health
#
# Their Barraskewda attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 87 damage, HP: -7
#
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Wugtrio has 35 starting health
#
# Their Wugtrio attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 71 damage, HP: 9
#
# Your Toedscruel attacked Wugtrio,
#       Its super effective!
#       Wugtrio took 65 damage, HP: -30
#
# Wugtrio fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Quaxwell has 70 starting health
#
# Your Toedscruel attacked Quaxwell,
#       Its super effective!
#       Quaxwell took 62 damage, HP: 8
#
# Their Quaxwell attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 61 damage, HP: 19
#
# Your Toedscruel attacked Quaxwell,
#       Its super effective!
#       Quaxwell took 62 damage, HP: -54
#
#
# Quaxwell fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Morgrem has 65 starting health
#
# Your Toedscruel attacked Morgrem,
#       Morgrem took 36 damage, HP: 29
#
# Their Morgrem attacked Toedscruel,
#       Toedscruel took 22 damage, HP: 58
#
# Your Toedscruel attacked Morgrem,
#       Morgrem took 36 damage, HP: -7
#
#
# Morgrem fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Houndstone has 72 starting health
#
# Your Toedscruel attacked Houndstone,
#       Houndstone took 20 damage, HP: 52
#
# Their Houndstone attacked Toedscruel,
#       Toedscruel took 36 damage, HP: 44
#
# Your Toedscruel attacked Houndstone,
#       Houndstone took 20 damage, HP: 32
#
# Their Houndstone attacked Toedscruel,
#       Toedscruel took 36 damage, HP: 8
#
# Your Toedscruel attacked Houndstone,
#       Houndstone took 20 damage, HP: 12
#
# Their Houndstone attacked Toedscruel,
#       Toedscruel took 36 damage, HP: -28
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Fuecoco has 67 starting health
#
# Your Toedscruel attacked Fuecoco,
#       Its not very effective
#       Fuecoco took 23 damage, HP: 44
#
# Their Fuecoco attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 34 damage, HP: 46
#
# Your Toedscruel attacked Fuecoco,
#       Its not very effective
#       Fuecoco took 23 damage, HP: 21
#
# Their Fuecoco attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 34 damage, HP: 12
#
# Your Toedscruel attacked Fuecoco,
#       Its not very effective
#       Fuecoco took 23 damage, HP: -2
#
#
# Fuecoco fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Tinkatuff has 65 starting health
#
# Your Toedscruel attacked Tinkatuff,
#       Its not very effective
#       Tinkatuff took 15 damage, HP: 50
#
# Their Tinkatuff attacked Toedscruel,
#       Toedscruel took 20 damage, HP: 60
#
# Your Toedscruel attacked Tinkatuff,
#       Its not very effective
#       Tinkatuff took 15 damage, HP: 35
#
# Their Tinkatuff attacked Toedscruel,
#       Toedscruel took 20 damage, HP: 40
#
# Your Toedscruel attacked Tinkatuff,
#       Its not very effective
#       Tinkatuff took 15 damage, HP: 20
#
# Their Tinkatuff attacked Toedscruel,
#       Toedscruel took 20 damage, HP: 20
#
# Your Toedscruel attacked Tinkatuff,
#       Its not very effective
#       Tinkatuff took 15 damage, HP: 5
#
# Their Tinkatuff attacked Toedscruel,
#       Toedscruel took 20 damage, HP: 0
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Stonjourner has 100 starting health
#
# Your Toedscruel attacked Stonjourner,
#       Its super effective!
#       Stonjourner took 180 damage, HP: -80
#
#
# Stonjourner fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Skeledirge has 104 starting health
#
# Your Toedscruel attacked Skeledirge,
#       Its not very effective
#       Skeledirge took 12 damage, HP: 92
#
# Their Skeledirge attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 54 damage, HP: 26
#
# Your Toedscruel attacked Skeledirge,
#       Its not very effective
#       Skeledirge took 12 damage, HP: 80
#
# Their Skeledirge attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 54 damage, HP: -28
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Hatterene has 57 starting health
#
# Your Toedscruel attacked Hatterene,
#       Hatterene took 19 damage, HP: 38
#
# Their Hatterene attacked Toedscruel,
#       Toedscruel took 32 damage, HP: 48
#
# Your Toedscruel attacked Hatterene,
#       Hatterene took 19 damage, HP: 19
#
# Their Hatterene attacked Toedscruel,
#       Toedscruel took 32 damage, HP: 16
#
# Your Toedscruel attacked Hatterene,
#       Hatterene took 19 damage, HP: 0
#
#
# Hatterene fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Palafin has 100 starting health
#
# Their Palafin attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 51 damage, HP: 29
#
# Your Toedscruel attacked Palafin,
#       Its super effective!
#       Palafin took 60 damage, HP: 40
#
# Their Palafin attacked Toedscruel,
#       Its super effective!
#       Toedscruel took 51 damage, HP: -22
#
#
# Toedscruel fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Indeedee has 60 starting health
#
# Your Toedscruel attacked Indeedee,
#       Indeedee took 30 damage, HP: 30
#
# Their Indeedee attacked Toedscruel,
#       Toedscruel took 24 damage, HP: 56
#
# Your Toedscruel attacked Indeedee,
#       Indeedee took 30 damage, HP: 0
#
#
# Indeedee fainted
#
# -------------------------------------------
# Toedscruel has 80 starting health
# Glimmet has 48 starting health
#
# Your Toedscruel attacked Glimmet,
#       Its super effective!
#       Glimmet took 77 damage, HP: -29
#
#
# Glimmet fainted
#
# -------------------------------------------
# Toedscruel won 54.166666666666664% of battles
